# %% [markdown]
# # Modules for data: pandas
#
# Here we will use the mcd-menu.csv file, which you can download here:
#
# [mcd-menu.csv](https://raw.githubusercontent.com/UCSD-CSS-001/ucsd-css-001.github.io/main/live/mcd-menu.csv)

# %% [markdown]
# ## Wherefore modules?
#
# [pypi.org](pypi.org) has 324k packages.  From web servers, to machine learning frameworks, to video games, to bitcoin wallets, to recipe managers, to astronomy databases, etc.
#
# There are millions of different classes, functions, constants, in these packages.
#
# 1. we can't load them all in memory
#
# 2. we can't ask someone writing the next python MIDI music library to check all other previous libraries to make sure no one has used the class names they have in mind.
#
# Modules create namespaces, and modules manage what is loaded into memory.

# %%
import math

# %%
math.log(4)
# Out:
# 1.3862943611198906

# %% [markdown]
# ### What's a module?

# %%
import edsmodule

# %%
dir(edsmodule)
# Out:
# ['TestClass',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'bigstring',
#  'gigantify']

# %%
edsmodule.bigstring
# Out:
# 'these are all the thoughts I ever had, in one string: hmm......'

# %%
edsmodule.gigantify(4)
# Out:
# 4294967296

# %%
obj = edsmodule.TestClass(3)

# %%
type(obj)
# Out:
# edsmodule.TestClass

# %%
import edsmodule as ed

# %%
ed.bigstring
# Out:
# 'these are all the thoughts I ever had, in one string: hmm......'

# %%
from edsmodule import bigstring

# %%
bigstring
# Out:
# 'these are all the thoughts I ever had, in one string: hmm......'

# %%
from edsmodule import bigstring as bs

# %%
bs
# Out:
# 'these are all the thoughts I ever had, in one string: hmm......'

# %% [markdown]
# ## Importing approaches

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Tabular data and DataFrame

# %%
import pandas as pd

# %% [markdown]
# ### Why tabular data

# %%
names = ['alice', 'bob', 'carol', 'david']
heights = [68, 70, 65, 72]
weight = [130, 150, 170, 180]

# %%
bmi = []
for i in range(len(heights)):
    bmi.append(703 * weight[i] / heights[i]**2) #

# %%
big_bmi_people = []
for i in range(len(heights)):
    if bmi[i] > 24:
        big_bmi_people.append(names[i])

# %%
big_bmi_people
# Out:
# ['carol', 'david']

# %%
people = []
for n,h,w in zip(names, heights, weight):
    people.append({'name':n, 'height':h, 'weight':w})

# %%
for person in people:
    if (703*person['weight']/person['height']**2) > 24:
        print(person)
# Out:
# {'name': 'carol', 'height': 65, 'weight': 170}
# {'name': 'david', 'height': 72, 'weight': 180}

# %%
df = pd.DataFrame({'name':names, 
                   'height':heights, 
                   'weight': weight})

# %%
df
# Out:
#     name  height  weight
# 0  alice      68     130
# 1    bob      70     150
# 2  carol      65     170
# 3  david      72     180

# %% [markdown]
# ## What is a Data Frame?
#
# ### Foundational data structures
#
# #### numpy arrays
#
# differences from lists?  single type.  supports elementwise operations.  handy built in functions.

# %%
import numpy as np

x = [1, 2, 3, 4, 5]
x_array = np.array(x)

# %%
x_array
# Out:
# array([1, 2, 3, 4, 5])

# %%
# generate a new list: y = x**2
y = []
for item in x:
    y.append(item**2)
y
# Out:
# [1, 4, 9, 16, 25]

# %%
y_array = x_array ** 2
y_array
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
h = np.array(heights)
w = np.array(weight)

# %%
bmi = 703 * w / h**2
bmi
# Out:
# array([19.76427336, 21.52040816, 28.28639053, 24.40972222])

# %%
pronoun = np.array(['he', 'she', 'ze', 'fe'])

# %%
pronoun == 'he'
# Out:
# array([ True, False, False, False])

# %%
['he', 'she', 'ze', 'fe'] == 'he'
# Out:
# False

# %%
h.prod()
# Out:
# 22276800

# %% [markdown]
# #### pandas series
#
# kinda like an array, kinda like a dictionary.  .values and .index.  We use it mostly like an array.

# %%
print(heights, names)
# Out:
# [68, 70, 65, 72] ['alice', 'bob', 'carol', 'david']

# %%
h = pd.Series(heights, index = names)

# %%
h
# Out:
# alice    68
# bob      70
# carol    65
# david    72
# dtype: int64

# %%
h ** 2
# Out:
# alice    4624
# bob      4900
# carol    4225
# david    5184
# dtype: int64

# %%
h.iloc[3]
# Out:
# 72

# %%
h + 100
# Out:
# alice    168
# bob      170
# carol    165
# david    172
# dtype: int64

# %% [markdown]
# #### pandas dataframe
#
# kinda like a 2d array / matrix, kinda like a dictionary of column-series, kinda like a dictionary of row-series

# %%
df = pd.DataFrame({'name': names, 'height': heights, 'weight':weight})

# %%
df['name'][2:]
# Out:
# 2    carol
# 3    david
# Name: name, dtype: object

# %% [markdown]
# ## csv and read_csv()

# %%
mcd = pd.read_csv('mcd-menu.csv')

# %%
mcd
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# ..                         ...            ...                            ...
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 257                         17            6.0                             29
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...             31                             10
# 1          0.0  ...             30                             10
# 2          0.0  ...             29                             10
# 3          0.0  ...             30                             10
# 4          0.0  ...             30                             10
# ..         ...  ...            ...                            ...
# 255        0.5  ...             80                             27
# 256        1.0  ...            106                             35
# 257        0.0  ...             53                             18
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                             17       3       17
# 1                4                             17       3       18
# 2                4                             17       2       14
# 3                4                             17       2       21
# 4                4                             17       2       21
# ..             ...                            ...     ...      ...
# 255              1                              4      64       12
# 256              1                              5      85       15
# 257              1                              2      43        8
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# ..                         ...                        ...
# 255                         15                          0
# 256                         20                          0
# 257                         10                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                         25                    15
# 1                         25                     8
# 2                         25                    10
# 3                         30                    15
# 4                         25                    10
# ..                       ...                   ...
# 255                       40                     8
# 256                       50                    10
# 257                       25                     6
# 258                       60                     6
# 259                       30                     4
#
# [260 rows x 24 columns]

# %% [markdown]
# ## DataFrame operations
#
# ### describe this thing to me

# %%
mcd.shape
# Out:
# (260, 24)

# %%
list(mcd.columns)
# Out:
# ['Category',
#  'Item',
#  'Serving Size',
#  'Calories',
#  'Calories from Fat',
#  'Total Fat',
#  'Total Fat (% Daily Value)',
#  'Saturated Fat',
#  'Saturated Fat (% Daily Value)',
#  'Trans Fat',
#  'Cholesterol',
#  'Cholesterol (% Daily Value)',
#  'Sodium',
#  'Sodium (% Daily Value)',
#  'Carbohydrates',
#  'Carbohydrates (% Daily Value)',
#  'Dietary Fiber',
#  'Dietary Fiber (% Daily Value)',
#  'Sugars',
#  'Protein',
#  'Vitamin A (% Daily Value)',
#  'Vitamin C (% Daily Value)',
#  'Calcium (% Daily Value)',
#  'Iron (% Daily Value)']

# %% [markdown]
# ### head and tail

# %%
mcd.tail(3)
# Out:
#                Category                                               Item  \
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 257                         17            6.0                             29
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 257        0.0  ...             53                             18
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 257              1                              2      43        8
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 257                         10                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 257                       25                     6
# 258                       60                     6
# 259                       30                     4
#
# [3 rows x 24 columns]

# %% [markdown]
# ### selecting columns

# %%
mcd['Calories']
# Out:
# 0      300
# 1      250
# 2      370
# 3      450
# 4      400
#       ...
# 255    510
# 256    690
# 257    340
# 258    810
# 259    410
# Name: Calories, Length: 260, dtype: int64

# %%
mcd[['Calories', 'Saturated Fat']]
# Out:
#      Calories  Saturated Fat
# 0         300            5.0
# 1         250            3.0
# 2         370            8.0
# 3         450           10.0
# 4         400            8.0
# ..        ...            ...
# 255       510            9.0
# 256       690           12.0
# 257       340            6.0
# 258       810           15.0
# 259       410            8.0
#
# [260 rows x 2 columns]

# %% [markdown]
# ### selecting rows by position

# %%
mcd.iloc[0:2]
# Out:
#     Category               Item    Serving Size  Calories  Calories from Fat  \
# 0  Breakfast       Egg McMuffin  4.8 oz (136 g)       300                120
# 1  Breakfast  Egg White Delight  4.8 oz (135 g)       250                 70
#
#    Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0       13.0                         20            5.0
# 1        8.0                         12            3.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
#
# [2 rows x 24 columns]

# %% [markdown]
# ### selecting cells

# %%
mcd
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# ..                         ...            ...                            ...
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 257                         17            6.0                             29
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...             31                             10
# 1          0.0  ...             30                             10
# 2          0.0  ...             29                             10
# 3          0.0  ...             30                             10
# 4          0.0  ...             30                             10
# ..         ...  ...            ...                            ...
# 255        0.5  ...             80                             27
# 256        1.0  ...            106                             35
# 257        0.0  ...             53                             18
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                             17       3       17
# 1                4                             17       3       18
# 2                4                             17       2       14
# 3                4                             17       2       21
# 4                4                             17       2       21
# ..             ...                            ...     ...      ...
# 255              1                              4      64       12
# 256              1                              5      85       15
# 257              1                              2      43        8
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# ..                         ...                        ...
# 255                         15                          0
# 256                         20                          0
# 257                         10                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                         25                    15
# 1                         25                     8
# 2                         25                    10
# 3                         30                    15
# 4                         25                    10
# ..                       ...                   ...
# 255                       40                     8
# 256                       50                    10
# 257                       25                     6
# 258                       60                     6
# 259                       30                     4
#
# [260 rows x 24 columns]

# %%
mcd['Calories'].iloc[0]
# Out:
# 300

# %%
mcd['Calories'][0]
# Out:
# 300

# %%
mcd = mcd.sort_values('Calories')

# %%
mcd['Item'].iloc[0]
# Out:
# 'Diet Dr Pepper (Child)'

# %%
mcd
# Out:
#            Category                                               Item  \
# 125       Beverages                             Diet Dr Pepper (Child)
# 138    Coffee & Tea                                  Iced Tea (Medium)
# 137    Coffee & Tea                                   Iced Tea (Small)
# 136       Beverages                                Dasani Water Bottle
# 145    Coffee & Tea                                     Coffee (Small)
# ..              ...                                                ...
# 33        Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34        Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31        Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32        Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82   Chicken & Fish                       Chicken McNuggets (40 piece)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 125     12 fl oz cup         0                  0        0.0
# 138     21 fl oz cup         0                  0        0.0
# 137     16 fl oz cup         0                  0        0.0
# 136       16.9 fl oz         0                  0        0.0
# 145     12 fl oz cup         0                  0        0.0
# ..               ...       ...                ...        ...
# 33   14.9 oz (423 g)       990                410       46.0
# 34   15.4 oz (437 g)      1050                450       50.0
# 31   14.8 oz (420 g)      1090                510       56.0
# 32   15.3 oz (434 g)      1150                540       60.0
# 82   22.8 oz (646 g)      1880               1060      118.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 125                          0            0.0                              0
# 138                          0            0.0                              0
# 137                          0            0.0                              0
# 136                          0            0.0                              0
# 145                          0            0.0                              0
# ..                         ...            ...                            ...
# 33                          70           16.0                             78
# 34                          77           16.0                             81
# 31                          87           19.0                             96
# 32                          93           20.0                            100
# 82                         182           20.0                            101
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 125        0.0  ...              0                              0
# 138        0.0  ...              0                              0
# 137        0.0  ...              0                              0
# 136        0.0  ...              0                              0
# 145        0.0  ...              0                              0
# ..         ...  ...            ...                            ...
# 33         0.0  ...            110                             37
# 34         0.0  ...            115                             38
# 31         0.0  ...            111                             37
# 32         0.0  ...            116                             39
# 82         1.0  ...            118                             39
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 125              0                              0       0        1
# 138              0                              0       0        0
# 137              0                              0       0        0
# 136              0                              0       0        0
# 145              0                              0       0        0
# ..             ...                            ...     ...      ...
# 33               6                             23      17       35
# 34               7                             28      18       35
# 31               6                             23      17       36
# 32               7                             28      17       36
# 82               6                             24       1       87
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 125                          0                          0
# 138                          0                          0
# 137                          0                          0
# 136                          0                          0
# 145                          0                          0
# ..                         ...                        ...
# 33                           0                          2
# 34                           4                          2
# 31                          15                          2
# 32                          15                          2
# 82                           0                         15
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 125                        0                     0
# 138                        0                     0
# 137                        0                     0
# 136                        0                     0
# 145                        0                     0
# ..                       ...                   ...
# 33                        25                    30
# 34                        25                    30
# 31                        25                    40
# 32                        30                    40
# 82                         8                    25
#
# [260 rows x 24 columns]

# %% [markdown]
# ### filtering rows via logical indexing

# %%
mcd[ mcd['Calories'] >= 1000 ]
# Out:
#           Category                                               Item  \
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 34  15.4 oz (437 g)      1050                450       50.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 32  15.3 oz (434 g)      1150                540       60.0
# 82  22.8 oz (646 g)      1880               1060      118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 34                         77           16.0                             81
# 31                         87           19.0                             96
# 32                         93           20.0                            100
# 82                        182           20.0                            101
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 34        0.0  ...            115                             38
# 31        0.0  ...            111                             37
# 32        0.0  ...            116                             39
# 82        1.0  ...            118                             39
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 34              7                             28      18       35
# 31              6                             23      17       36
# 32              7                             28      17       36
# 82              6                             24       1       87
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 34                          4                          2
# 31                         15                          2
# 32                         15                          2
# 82                          0                         15
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 34                       25                    30
# 31                       25                    40
# 32                       30                    40
# 82                        8                    25
#
# [4 rows x 24 columns]

# %%
mcd[ mcd['Category'] == 'Breakfast' ]
# Out:
#      Category                                               Item  \
# 38  Breakfast                                         Hash Brown
# 1   Breakfast                                  Egg White Delight
# 41  Breakfast          Fruit & Maple Oatmeal without Brown Sugar
# 40  Breakfast                              Fruit & Maple Oatmeal
# 0   Breakfast                                       Egg McMuffin
# 37  Breakfast                                    Sausage Burrito
# 35  Breakfast                                           Hotcakes
# 2   Breakfast                                   Sausage McMuffin
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 16  Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 21  Breakfast                                 Sausage McGriddles
# 10  Breakfast                  Sausage Biscuit (Regular Biscuit)
# 5   Breakfast                               Steak & Egg McMuffin
# 3   Breakfast                          Sausage McMuffin with Egg
# 6   Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 19  Breakfast                     Bacon, Egg & Cheese McGriddles
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 39  Breakfast                                     Cinnamon Melts
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 17  Breakfast     Southern Style Chicken Biscuit (Large Biscuit)
# 11  Breakfast                    Sausage Biscuit (Large Biscuit)
# 23  Breakfast   Sausage, Egg & Cheese McGriddles with Egg Whites
# 12  Breakfast         Sausage Biscuit with Egg (Regular Biscuit)
# 7   Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 36  Breakfast                               Hotcakes and Sausage
# 15  Breakfast    Sausage Biscuit with Egg Whites (Large Biscuit)
# 18  Breakfast              Steak & Egg Biscuit (Regular Biscuit)
# 22  Breakfast                   Sausage, Egg & Cheese McGriddles
# 13  Breakfast           Sausage Biscuit with Egg (Large Biscuit)
# 25  Breakfast          Bacon, Egg & Cheese Bagel with Egg Whites
# 24  Breakfast                          Bacon, Egg & Cheese Bagel
# 29  Breakfast    Big Breakfast with Egg Whites (Regular Biscuit)
# 26  Breakfast                          Steak, Egg & Cheese Bagel
# 30  Breakfast      Big Breakfast with Egg Whites (Large Biscuit)
# 27  Breakfast                    Big Breakfast (Regular Biscuit)
# 28  Breakfast                      Big Breakfast (Large Biscuit)
# 33  Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31  Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32  Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 38      2 oz (56 g)       150                 80        9.0
# 1    4.8 oz (135 g)       250                 70        8.0
# 41   9.6 oz (251 g)       260                 40        4.0
# 40   9.6 oz (251 g)       290                 35        4.0
# 0    4.8 oz (136 g)       300                120       13.0
# 37   3.9 oz (111 g)       300                150       16.0
# 35   5.3 oz (151 g)       350                 80        9.0
# 2    3.9 oz (111 g)       370                200       23.0
# 4    5.7 oz (161 g)       400                210       23.0
# 20   6.3 oz (178 g)       400                140       15.0
# 16     5 oz (143 g)       410                180       20.0
# 8    5.4 oz (153 g)       410                180       20.0
# 21     5 oz (141 g)       420                200       22.0
# 10   4.1 oz (117 g)       430                240       27.0
# 5    6.5 oz (185 g)       430                210       23.0
# 3    5.7 oz (161 g)       450                250       28.0
# 6    5.3 oz (150 g)       460                230       26.0
# 19   6.1 oz (174 g)       460                190       21.0
# 14   5.9 oz (167 g)       460                250       27.0
# 39     4 oz (114 g)       460                170       19.0
# 9    5.9 oz (167 g)       470                220       25.0
# 17   5.5 oz (157 g)       470                220       24.0
# 11   4.6 oz (131 g)       480                280       31.0
# 23   7.2 oz (205 g)       500                230       26.0
# 12   5.7 oz (163 g)       510                290       33.0
# 7    5.8 oz (164 g)       520                270       30.0
# 36   6.8 oz (192 g)       520                210       24.0
# 15   6.4 oz (181 g)       520                280       32.0
# 18   7.1 oz (201 g)       540                290       32.0
# 22   7.1 oz (201 g)       550                280       31.0
# 13   6.2 oz (177 g)       570                330       37.0
# 25   7.1 oz (201 g)       570                230       25.0
# 24   6.9 oz (197 g)       620                280       31.0
# 29   9.6 oz (272 g)       640                330       37.0
# 26   8.5 oz (241 g)       670                310       35.0
# 30  10.1 oz (286 g)       690                370       41.0
# 27   9.5 oz (269 g)       740                430       48.0
# 28    10 oz (283 g)       800                470       52.0
# 33  14.9 oz (423 g)       990                410       46.0
# 34  15.4 oz (437 g)      1050                450       50.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 32  15.3 oz (434 g)      1150                540       60.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 38                         14            1.5                              6
# 1                          12            3.0                             15
# 41                          6            1.5                              8
# 40                          6            1.5                              8
# 0                          20            5.0                             25
# 37                         25            7.0                             33
# 35                         13            2.0                              9
# 2                          35            8.0                             42
# 4                          35            8.0                             42
# 20                         24            7.0                             34
# 16                         31            8.0                             41
# 8                          32           11.0                             56
# 21                         34            8.0                             40
# 10                         42           12.0                             62
# 5                          36            9.0                             46
# 3                          43           10.0                             52
# 6                          40           13.0                             65
# 19                         32            9.0                             44
# 14                         42           12.0                             62
# 39                         30            9.0                             43
# 9                          38           12.0                             59
# 17                         37            9.0                             45
# 11                         48           13.0                             65
# 23                         40           10.0                             52
# 12                         50           14.0                             71
# 7                          47           14.0                             68
# 36                         37            7.0                             36
# 15                         49           13.0                             65
# 18                         49           16.0                             78
# 22                         48           12.0                             61
# 13                         57           15.0                             74
# 25                         39            9.0                             45
# 24                         48           11.0                             56
# 29                         57           14.0                             69
# 26                         53           13.0                             63
# 30                         63           14.0                             72
# 27                         73           17.0                             87
# 28                         80           18.0                             90
# 33                         70           16.0                             78
# 34                         77           16.0                             81
# 31                         87           19.0                             96
# 32                         93           20.0                            100
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 38        0.0  ...             15                              5
# 1         0.0  ...             30                             10
# 41        0.0  ...             49                             16
# 40        0.0  ...             58                             19
# 0         0.0  ...             31                             10
# 37        0.0  ...             26                              9
# 35        0.0  ...             60                             20
# 2         0.0  ...             29                             10
# 4         0.0  ...             30                             10
# 20        0.0  ...             47                             16
# 16        0.0  ...             41                             14
# 8         0.0  ...             36                             12
# 21        0.0  ...             44                             15
# 10        0.0  ...             34                             11
# 5         1.0  ...             31                             10
# 3         0.0  ...             30                             10
# 6         0.0  ...             38                             13
# 19        0.0  ...             48                             16
# 14        0.0  ...             34                             11
# 39        0.0  ...             66                             22
# 9         0.0  ...             42                             14
# 17        0.0  ...             46                             15
# 11        0.0  ...             39                             13
# 23        0.0  ...             46                             15
# 12        0.0  ...             36                             12
# 7         0.0  ...             43                             14
# 36        0.0  ...             61                             20
# 15        0.0  ...             40                             13
# 18        1.0  ...             38                             13
# 22        0.0  ...             48                             16
# 13        0.0  ...             42                             14
# 25        0.5  ...             55                             18
# 24        0.5  ...             57                             19
# 29        0.0  ...             50                             17
# 26        1.5  ...             56                             19
# 30        0.0  ...             55                             18
# 27        0.0  ...             51                             17
# 28        0.0  ...             56                             19
# 33        0.0  ...            110                             37
# 34        0.0  ...            115                             38
# 31        0.0  ...            111                             37
# 32        0.0  ...            116                             39
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 38              2                              6       0        1
# 1               4                             17       3       18
# 41              5                             22      18        5
# 40              5                             19      32        5
# 0               4                             17       3       17
# 37              1                              5       2       12
# 35              3                             10      14        8
# 2               4                             17       2       14
# 4               4                             17       2       21
# 20              2                              9      16       20
# 16              2                              6       3       17
# 8               2                              7       3       20
# 21              2                              8      15       11
# 10              2                              6       2       11
# 5               4                             18       3       26
# 3               4                             17       2       21
# 6               2                              7       3       19
# 19              2                              9      15       19
# 14              2                              6       3       18
# 39              3                             11      32        6
# 9               3                             12       4       20
# 17              3                             11       4       17
# 11              3                             11       3       11
# 23              2                              9      15       21
# 12              2                              6       2       18
# 7               3                             12       4       19
# 36              3                             10      14       15
# 15              3                             11       3       18
# 18              2                              8       3       25
# 22              2                              9      15       20
# 13              3                             11       3       18
# 25              3                             12       8       30
# 24              3                             11       7       30
# 29              3                             12       3       26
# 26              3                             12       7       33
# 30              4                             17       4       26
# 27              3                             12       3       28
# 28              4                             17       3       28
# 33              6                             23      17       35
# 34              7                             28      18       35
# 31              6                             23      17       36
# 32              7                             28      17       36
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 38                          0                          2
# 1                           6                          0
# 41                          2                        130
# 40                          2                        130
# 0                          10                          0
# 37                         10                          2
# 35                          0                          0
# 2                           8                          0
# 4                           6                          0
# 20                          2                         10
# 16                          0                          2
# 8                           2                          8
# 21                          0                          0
# 10                          0                          0
# 5                          15                          2
# 3                          15                          0
# 6                          10                          8
# 19                         10                         10
# 14                          0                          0
# 39                          4                          0
# 9                           6                          8
# 17                          4                          2
# 11                          4                          0
# 23                          2                          0
# 12                          6                          0
# 7                          15                          8
# 36                          0                          0
# 15                          4                          0
# 18                         10                          2
# 22                         10                          0
# 13                         10                          0
# 25                         10                         15
# 24                         20                         15
# 29                          0                          2
# 26                         20                          4
# 30                          4                          2
# 27                         15                          2
# 28                         15                          2
# 33                          0                          2
# 34                          4                          2
# 31                         15                          2
# 32                         15                          2
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 38                        0                     2
# 1                        25                     8
# 41                        6                    10
# 40                       10                    10
# 0                        25                    15
# 37                       15                    15
# 35                       15                    15
# 2                        25                    10
# 4                        25                    10
# 20                       15                    10
# 16                        6                    15
# 8                        15                    10
# 21                        8                    10
# 10                        6                    15
# 5                        30                    20
# 3                        30                    15
# 6                        15                    15
# 19                       20                    15
# 14                        8                    15
# 39                        6                    15
# 9                        15                    15
# 17                        8                    15
# 11                        8                    15
# 23                       20                    10
# 12                       10                    20
# 7                        20                    20
# 36                       15                    15
# 15                        8                    15
# 18                       20                    25
# 22                       20                    15
# 13                       10                    20
# 25                       20                    15
# 24                       20                    20
# 29                       10                    15
# 26                       25                    25
# 30                       10                    15
# 27                       15                    25
# 28                       15                    30
# 33                       25                    30
# 34                       25                    30
# 31                       25                    40
# 32                       30                    40
#
# [42 rows x 24 columns]

# %%
mcd[ mcd['Category'] == 'Breakfast' ][ mcd['Calories'] > 300][ mcd['Calories'] < 500]
# Out:
# <ipython-input-59-de5846e98401>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mcd[ mcd['Category'] == 'Breakfast' ][ mcd['Calories'] > 300][ mcd['Calories'] < 500]
# <ipython-input-59-de5846e98401>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mcd[ mcd['Category'] == 'Breakfast' ][ mcd['Calories'] > 300][ mcd['Calories'] < 500]
#      Category                                               Item  \
# 35  Breakfast                                           Hotcakes
# 2   Breakfast                                   Sausage McMuffin
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 16  Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 21  Breakfast                                 Sausage McGriddles
# 10  Breakfast                  Sausage Biscuit (Regular Biscuit)
# 5   Breakfast                               Steak & Egg McMuffin
# 3   Breakfast                          Sausage McMuffin with Egg
# 6   Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 19  Breakfast                     Bacon, Egg & Cheese McGriddles
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 39  Breakfast                                     Cinnamon Melts
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 17  Breakfast     Southern Style Chicken Biscuit (Large Biscuit)
# 11  Breakfast                    Sausage Biscuit (Large Biscuit)
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 35  5.3 oz (151 g)       350                 80        9.0
# 2   3.9 oz (111 g)       370                200       23.0
# 4   5.7 oz (161 g)       400                210       23.0
# 20  6.3 oz (178 g)       400                140       15.0
# 16    5 oz (143 g)       410                180       20.0
# 8   5.4 oz (153 g)       410                180       20.0
# 21    5 oz (141 g)       420                200       22.0
# 10  4.1 oz (117 g)       430                240       27.0
# 5   6.5 oz (185 g)       430                210       23.0
# 3   5.7 oz (161 g)       450                250       28.0
# 6   5.3 oz (150 g)       460                230       26.0
# 19  6.1 oz (174 g)       460                190       21.0
# 14  5.9 oz (167 g)       460                250       27.0
# 39    4 oz (114 g)       460                170       19.0
# 9   5.9 oz (167 g)       470                220       25.0
# 17  5.5 oz (157 g)       470                220       24.0
# 11  4.6 oz (131 g)       480                280       31.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 35                         13            2.0                              9
# 2                          35            8.0                             42
# 4                          35            8.0                             42
# 20                         24            7.0                             34
# 16                         31            8.0                             41
# 8                          32           11.0                             56
# 21                         34            8.0                             40
# 10                         42           12.0                             62
# 5                          36            9.0                             46
# 3                          43           10.0                             52
# 6                          40           13.0                             65
# 19                         32            9.0                             44
# 14                         42           12.0                             62
# 39                         30            9.0                             43
# 9                          38           12.0                             59
# 17                         37            9.0                             45
# 11                         48           13.0                             65
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 35        0.0  ...             60                             20
# 2         0.0  ...             29                             10
# 4         0.0  ...             30                             10
# 20        0.0  ...             47                             16
# 16        0.0  ...             41                             14
# 8         0.0  ...             36                             12
# 21        0.0  ...             44                             15
# 10        0.0  ...             34                             11
# 5         1.0  ...             31                             10
# 3         0.0  ...             30                             10
# 6         0.0  ...             38                             13
# 19        0.0  ...             48                             16
# 14        0.0  ...             34                             11
# 39        0.0  ...             66                             22
# 9         0.0  ...             42                             14
# 17        0.0  ...             46                             15
# 11        0.0  ...             39                             13
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 35              3                             10      14        8
# 2               4                             17       2       14
# 4               4                             17       2       21
# 20              2                              9      16       20
# 16              2                              6       3       17
# 8               2                              7       3       20
# 21              2                              8      15       11
# 10              2                              6       2       11
# 5               4                             18       3       26
# 3               4                             17       2       21
# 6               2                              7       3       19
# 19              2                              9      15       19
# 14              2                              6       3       18
# 39              3                             11      32        6
# 9               3                             12       4       20
# 17              3                             11       4       17
# 11              3                             11       3       11
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 35                          0                          0
# 2                           8                          0
# 4                           6                          0
# 20                          2                         10
# 16                          0                          2
# 8                           2                          8
# 21                          0                          0
# 10                          0                          0
# 5                          15                          2
# 3                          15                          0
# 6                          10                          8
# 19                         10                         10
# 14                          0                          0
# 39                          4                          0
# 9                           6                          8
# 17                          4                          2
# 11                          4                          0
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 35                       15                    15
# 2                        25                    10
# 4                        25                    10
# 20                       15                    10
# 16                        6                    15
# 8                        15                    10
# 21                        8                    10
# 10                        6                    15
# 5                        30                    20
# 3                        30                    15
# 6                        15                    15
# 19                       20                    15
# 14                        8                    15
# 39                        6                    15
# 9                        15                    15
# 17                        8                    15
# 11                        8                    15
#
# [17 rows x 24 columns]

# %%
mcd[ (mcd['Category'] == 'Breakfast') & 
  (mcd['Calories'] > 300) & 
  (mcd['Calories'] < 500) ]
# Out:
#      Category                                               Item  \
# 35  Breakfast                                           Hotcakes
# 2   Breakfast                                   Sausage McMuffin
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 16  Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 21  Breakfast                                 Sausage McGriddles
# 10  Breakfast                  Sausage Biscuit (Regular Biscuit)
# 5   Breakfast                               Steak & Egg McMuffin
# 3   Breakfast                          Sausage McMuffin with Egg
# 6   Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 19  Breakfast                     Bacon, Egg & Cheese McGriddles
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 39  Breakfast                                     Cinnamon Melts
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 17  Breakfast     Southern Style Chicken Biscuit (Large Biscuit)
# 11  Breakfast                    Sausage Biscuit (Large Biscuit)
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 35  5.3 oz (151 g)       350                 80        9.0
# 2   3.9 oz (111 g)       370                200       23.0
# 4   5.7 oz (161 g)       400                210       23.0
# 20  6.3 oz (178 g)       400                140       15.0
# 16    5 oz (143 g)       410                180       20.0
# 8   5.4 oz (153 g)       410                180       20.0
# 21    5 oz (141 g)       420                200       22.0
# 10  4.1 oz (117 g)       430                240       27.0
# 5   6.5 oz (185 g)       430                210       23.0
# 3   5.7 oz (161 g)       450                250       28.0
# 6   5.3 oz (150 g)       460                230       26.0
# 19  6.1 oz (174 g)       460                190       21.0
# 14  5.9 oz (167 g)       460                250       27.0
# 39    4 oz (114 g)       460                170       19.0
# 9   5.9 oz (167 g)       470                220       25.0
# 17  5.5 oz (157 g)       470                220       24.0
# 11  4.6 oz (131 g)       480                280       31.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 35                         13            2.0                              9
# 2                          35            8.0                             42
# 4                          35            8.0                             42
# 20                         24            7.0                             34
# 16                         31            8.0                             41
# 8                          32           11.0                             56
# 21                         34            8.0                             40
# 10                         42           12.0                             62
# 5                          36            9.0                             46
# 3                          43           10.0                             52
# 6                          40           13.0                             65
# 19                         32            9.0                             44
# 14                         42           12.0                             62
# 39                         30            9.0                             43
# 9                          38           12.0                             59
# 17                         37            9.0                             45
# 11                         48           13.0                             65
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 35        0.0  ...             60                             20
# 2         0.0  ...             29                             10
# 4         0.0  ...             30                             10
# 20        0.0  ...             47                             16
# 16        0.0  ...             41                             14
# 8         0.0  ...             36                             12
# 21        0.0  ...             44                             15
# 10        0.0  ...             34                             11
# 5         1.0  ...             31                             10
# 3         0.0  ...             30                             10
# 6         0.0  ...             38                             13
# 19        0.0  ...             48                             16
# 14        0.0  ...             34                             11
# 39        0.0  ...             66                             22
# 9         0.0  ...             42                             14
# 17        0.0  ...             46                             15
# 11        0.0  ...             39                             13
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 35              3                             10      14        8
# 2               4                             17       2       14
# 4               4                             17       2       21
# 20              2                              9      16       20
# 16              2                              6       3       17
# 8               2                              7       3       20
# 21              2                              8      15       11
# 10              2                              6       2       11
# 5               4                             18       3       26
# 3               4                             17       2       21
# 6               2                              7       3       19
# 19              2                              9      15       19
# 14              2                              6       3       18
# 39              3                             11      32        6
# 9               3                             12       4       20
# 17              3                             11       4       17
# 11              3                             11       3       11
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 35                          0                          0
# 2                           8                          0
# 4                           6                          0
# 20                          2                         10
# 16                          0                          2
# 8                           2                          8
# 21                          0                          0
# 10                          0                          0
# 5                          15                          2
# 3                          15                          0
# 6                          10                          8
# 19                         10                         10
# 14                          0                          0
# 39                          4                          0
# 9                           6                          8
# 17                          4                          2
# 11                          4                          0
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 35                       15                    15
# 2                        25                    10
# 4                        25                    10
# 20                       15                    10
# 16                        6                    15
# 8                        15                    10
# 21                        8                    10
# 10                        6                    15
# 5                        30                    20
# 3                        30                    15
# 6                        15                    15
# 19                       20                    15
# 14                        8                    15
# 39                        6                    15
# 9                        15                    15
# 17                        8                    15
# 11                        8                    15
#
# [17 rows x 24 columns]

# %%
(mcd['Category'] == 'Breakfast') & (mcd['Calories'] > 300)
# Out:
# 125    False
# 138    False
# 137    False
# 136    False
# 145    False
#        ...
# 33      True
# 34      True
# 31      True
# 32      True
# 82     False
# Length: 260, dtype: bool

# %%
(mcd['Category'] == 'Breakfast') & (mcd['Calories'] > 300)
# Out:
# 125    False
# 138    False
# 137    False
# 136    False
# 145    False
#        ...
# 33      True
# 34      True
# 31      True
# 32      True
# 82     False
# Length: 260, dtype: bool

# %%
mcd [ (mcd['Category'] == 'Breakfast') | (mcd['Calories'] > 300) ]
# Out:
#           Category                                               Item  \
# 38       Breakfast                                         Hash Brown
# 1        Breakfast                                  Egg White Delight
# 41       Breakfast          Fruit & Maple Oatmeal without Brown Sugar
# 40       Breakfast                              Fruit & Maple Oatmeal
# 0        Breakfast                                       Egg McMuffin
# ..             ...                                                ...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 38      2 oz (56 g)       150                 80        9.0
# 1    4.8 oz (135 g)       250                 70        8.0
# 41   9.6 oz (251 g)       260                 40        4.0
# 40   9.6 oz (251 g)       290                 35        4.0
# 0    4.8 oz (136 g)       300                120       13.0
# ..              ...       ...                ...        ...
# 33  14.9 oz (423 g)       990                410       46.0
# 34  15.4 oz (437 g)      1050                450       50.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 32  15.3 oz (434 g)      1150                540       60.0
# 82  22.8 oz (646 g)      1880               1060      118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 38                         14            1.5                              6
# 1                          12            3.0                             15
# 41                          6            1.5                              8
# 40                          6            1.5                              8
# 0                          20            5.0                             25
# ..                        ...            ...                            ...
# 33                         70           16.0                             78
# 34                         77           16.0                             81
# 31                         87           19.0                             96
# 32                         93           20.0                            100
# 82                        182           20.0                            101
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 38        0.0  ...             15                              5
# 1         0.0  ...             30                             10
# 41        0.0  ...             49                             16
# 40        0.0  ...             58                             19
# 0         0.0  ...             31                             10
# ..        ...  ...            ...                            ...
# 33        0.0  ...            110                             37
# 34        0.0  ...            115                             38
# 31        0.0  ...            111                             37
# 32        0.0  ...            116                             39
# 82        1.0  ...            118                             39
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 38              2                              6       0        1
# 1               4                             17       3       18
# 41              5                             22      18        5
# 40              5                             19      32        5
# 0               4                             17       3       17
# ..            ...                            ...     ...      ...
# 33              6                             23      17       35
# 34              7                             28      18       35
# 31              6                             23      17       36
# 32              7                             28      17       36
# 82              6                             24       1       87
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 38                          0                          2
# 1                           6                          0
# 41                          2                        130
# 40                          2                        130
# 0                          10                          0
# ..                        ...                        ...
# 33                          0                          2
# 34                          4                          2
# 31                         15                          2
# 32                         15                          2
# 82                          0                         15
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 38                        0                     2
# 1                        25                     8
# 41                        6                    10
# 40                       10                    10
# 0                        25                    15
# ..                      ...                   ...
# 33                       25                    30
# 34                       25                    30
# 31                       25                    40
# 32                       30                    40
# 82                        8                    25
#
# [150 rows x 24 columns]

# %% [markdown]
# - logical indexing.
# - make conjunctions by combining arrays of logical values with &
# - make disjunctions with |
# - and we need to put comparison operations in () before combing

# %% [markdown]
# **.isin()**

# %%
mcd['Category'].isin(['Beverages', 'Breakfast'])
# Out:
# 125     True
# 138    False
# 137    False
# 136     True
# 145    False
#        ...
# 33      True
# 34      True
# 31      True
# 32      True
# 82     False
# Name: Category, Length: 260, dtype: bool

# %%
(mcd['Category'] == 'Beverages') | (mcd['Category'] == 'Breakfast')
# Out:
# 125     True
# 138    False
# 137    False
# 136     True
# 145    False
#        ...
# 33      True
# 34      True
# 31      True
# 32      True
# 82     False
# Name: Category, Length: 260, dtype: bool

# %% [markdown]
# **pd.isna()**

# %%
mcd.iloc[4,3] = np.NaN

# %%
mcd [ mcd['Calories'].isna() ]
# Out:
#          Category            Item  Serving Size  Calories  Calories from Fat  \
# 145  Coffee & Tea  Coffee (Small)  12 fl oz cup       NaN                  0
#
#      Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 145        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 145                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 145                              0              0
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 145                              0       0        0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 145                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 145                        0                     0
#
# [1 rows x 24 columns]

# %% [markdown]
# ### indexes, loc and iloc
#
# ### make a new column

# %%
mcd['Hello'] = 'hi'

# %%
mcd['PF'] = mcd['Protein'] + mcd['Dietary Fiber']

# %%
mcd
# Out:
#            Category                                               Item  \
# 125       Beverages                             Diet Dr Pepper (Child)
# 138    Coffee & Tea                                  Iced Tea (Medium)
# 137    Coffee & Tea                                   Iced Tea (Small)
# 136       Beverages                                Dasani Water Bottle
# 145    Coffee & Tea                                     Coffee (Small)
# ..              ...                                                ...
# 33        Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34        Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31        Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32        Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82   Chicken & Fish                       Chicken McNuggets (40 piece)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 125     12 fl oz cup       0.0                  0        0.0
# 138     21 fl oz cup       0.0                  0        0.0
# 137     16 fl oz cup       0.0                  0        0.0
# 136       16.9 fl oz       0.0                  0        0.0
# 145     12 fl oz cup       NaN                  0        0.0
# ..               ...       ...                ...        ...
# 33   14.9 oz (423 g)     990.0                410       46.0
# 34   15.4 oz (437 g)    1050.0                450       50.0
# 31   14.8 oz (420 g)    1090.0                510       56.0
# 32   15.3 oz (434 g)    1150.0                540       60.0
# 82   22.8 oz (646 g)    1880.0               1060      118.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 125                          0            0.0                              0
# 138                          0            0.0                              0
# 137                          0            0.0                              0
# 136                          0            0.0                              0
# 145                          0            0.0                              0
# ..                         ...            ...                            ...
# 33                          70           16.0                             78
# 34                          77           16.0                             81
# 31                          87           19.0                             96
# 32                          93           20.0                            100
# 82                         182           20.0                            101
#
#      Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 125        0.0  ...              0                              0       0
# 138        0.0  ...              0                              0       0
# 137        0.0  ...              0                              0       0
# 136        0.0  ...              0                              0       0
# 145        0.0  ...              0                              0       0
# ..         ...  ...            ...                            ...     ...
# 33         0.0  ...              6                             23      17
# 34         0.0  ...              7                             28      18
# 31         0.0  ...              6                             23      17
# 32         0.0  ...              7                             28      17
# 82         1.0  ...              6                             24       1
#
#      Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 125        1                          0                          0
# 138        0                          0                          0
# 137        0                          0                          0
# 136        0                          0                          0
# 145        0                          0                          0
# ..       ...                        ...                        ...
# 33        35                          0                          2
# 34        35                          4                          2
# 31        36                         15                          2
# 32        36                         15                          2
# 82        87                          0                         15
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 125                        0                     0     hi   1
# 138                        0                     0     hi   0
# 137                        0                     0     hi   0
# 136                        0                     0     hi   0
# 145                        0                     0     hi   0
# ..                       ...                   ...    ...  ..
# 33                        25                    30     hi  41
# 34                        25                    30     hi  42
# 31                        25                    40     hi  42
# 32                        30                    40     hi  43
# 82                         8                    25     hi  93
#
# [260 rows x 26 columns]

# %% [markdown]
# ### sort_values

# %%
mcd = mcd.sort_values('PF')

# %%
mcd.sort_values('PF', ascending = False)
# Out:
#            Category                                         Item  \
# 82   Chicken & Fish                 Chicken McNuggets (40 piece)
# 47      Beef & Pork           Double Quarter Pounder with Cheese
# 81   Chicken & Fish                 Chicken McNuggets (20 piece)
# 64   Chicken & Fish     Bacon Clubhouse Grilled Chicken Sandwich
# 32        Breakfast  Big Breakfast with Hotcakes (Large Biscuit)
# ..              ...                                          ...
# 128       Beverages                               Sprite (Large)
# 117       Beverages                            Diet Coke (Child)
# 116       Beverages                            Diet Coke (Large)
# 112       Beverages                    Coca-Cola Classic (Large)
# 120       Beverages                            Dr Pepper (Large)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 82   22.8 oz (646 g)    1880.0               1060      118.0
# 47     10 oz (283 g)     750.0                380       43.0
# 81   11.4 oz (323 g)     940.0                530       59.0
# 64    9.5 oz (270 g)     590.0                230       25.0
# 32   15.3 oz (434 g)    1150.0                540       60.0
# ..               ...       ...                ...        ...
# 128     30 fl oz cup     280.0                  0        0.0
# 117     12 fl oz cup       0.0                  0        0.0
# 116     30 fl oz cup       0.0                  0        0.0
# 112     30 fl oz cup     280.0                  0        0.0
# 120     30 fl oz cup     270.0                  0        0.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 82                         182           20.0                            101
# 47                          66           19.0                             96
# 81                          91           10.0                             50
# 64                          39            8.0                             42
# 32                          93           20.0                            100
# ..                         ...            ...                            ...
# 128                          0            0.0                              0
# 117                          0            0.0                              0
# 116                          0            0.0                              0
# 112                          0            0.0                              0
# 120                          0            0.0                              0
#
#      Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 82         1.0  ...              6                             24       1
# 47         2.5  ...              3                             11      10
# 81         0.0  ...              3                             12       0
# 64         0.0  ...              4                             15      14
# 32         0.0  ...              7                             28      17
# ..         ...  ...            ...                            ...     ...
# 128        0.0  ...              0                              0      74
# 117        0.0  ...              0                              0       0
# 116        0.0  ...              0                              0       0
# 112        0.0  ...              0                              0      76
# 120        0.0  ...              0                              0      70
#
#      Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 82        87                          0                         15
# 47        48                         10                          2
# 81        44                          0                          8
# 64        40                          8                         30
# 32        36                         15                          2
# ..       ...                        ...                        ...
# 128        0                          0                          0
# 117        0                          0                          0
# 116        0                          0                          0
# 112        0                          0                          0
# 120        0                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 82                         8                    25     hi  93
# 47                        30                    35     hi  51
# 81                         4                    10     hi  47
# 64                        30                    15     hi  44
# 32                        30                    40     hi  43
# ..                       ...                   ...    ...  ..
# 128                        0                     0     hi   0
# 117                        0                     0     hi   0
# 116                        0                     0     hi   0
# 112                        0                     0     hi   0
# 120                        0                     0     hi   0
#
# [260 rows x 26 columns]

# %%
# we want the 3 items highest in 'Total Fat'
mcd.sort_values('Total Fat')[-3:]
# Out:
#           Category                                         Item  \
# 81  Chicken & Fish                 Chicken McNuggets (20 piece)
# 32       Breakfast  Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                 Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 81  11.4 oz (323 g)     940.0                530       59.0
# 32  15.3 oz (434 g)    1150.0                540       60.0
# 82  22.8 oz (646 g)    1880.0               1060      118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 81                         91           10.0                             50
# 32                         93           20.0                            100
# 82                        182           20.0                            101
#
#     Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 81        0.0  ...              3                             12       0
# 32        0.0  ...              7                             28      17
# 82        1.0  ...              6                             24       1
#
#     Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 81       44                          0                          8
# 32       36                         15                          2
# 82       87                          0                         15
#
#     Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 81                        4                    10     hi  47
# 32                       30                    40     hi  43
# 82                        8                    25     hi  93
#
# [3 rows x 26 columns]

# %%
mcd.sort_values('Total Fat').tail(3)
# Out:
#           Category                                         Item  \
# 81  Chicken & Fish                 Chicken McNuggets (20 piece)
# 32       Breakfast  Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                 Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 81  11.4 oz (323 g)     940.0                530       59.0
# 32  15.3 oz (434 g)    1150.0                540       60.0
# 82  22.8 oz (646 g)    1880.0               1060      118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 81                         91           10.0                             50
# 32                         93           20.0                            100
# 82                        182           20.0                            101
#
#     Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 81        0.0  ...              3                             12       0
# 32        0.0  ...              7                             28      17
# 82        1.0  ...              6                             24       1
#
#     Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 81       44                          0                          8
# 32       36                         15                          2
# 82       87                          0                         15
#
#     Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 81                        4                    10     hi  47
# 32                       30                    40     hi  43
# 82                        8                    25     hi  93
#
# [3 rows x 26 columns]

# %%
mcd.sort_values('Total Fat').iloc[-3:]
# Out:
#           Category                                         Item  \
# 81  Chicken & Fish                 Chicken McNuggets (20 piece)
# 32       Breakfast  Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                 Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 81  11.4 oz (323 g)     940.0                530       59.0
# 32  15.3 oz (434 g)    1150.0                540       60.0
# 82  22.8 oz (646 g)    1880.0               1060      118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 81                         91           10.0                             50
# 32                         93           20.0                            100
# 82                        182           20.0                            101
#
#     Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 81        0.0  ...              3                             12       0
# 32        0.0  ...              7                             28      17
# 82        1.0  ...              6                             24       1
#
#     Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 81       44                          0                          8
# 32       36                         15                          2
# 82       87                          0                         15
#
#     Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 81                        4                    10     hi  47
# 32                       30                    40     hi  43
# 82                        8                    25     hi  93
#
# [3 rows x 26 columns]

# %%
mcd.sort_values('Total Fat', ascending = False).head(3)
# Out:
#           Category                                         Item  \
# 82  Chicken & Fish                 Chicken McNuggets (40 piece)
# 32       Breakfast  Big Breakfast with Hotcakes (Large Biscuit)
# 81  Chicken & Fish                 Chicken McNuggets (20 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 82  22.8 oz (646 g)    1880.0               1060      118.0
# 32  15.3 oz (434 g)    1150.0                540       60.0
# 81  11.4 oz (323 g)     940.0                530       59.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 82                        182           20.0                            101
# 32                         93           20.0                            100
# 81                         91           10.0                             50
#
#     Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 82        1.0  ...              6                             24       1
# 32        0.0  ...              7                             28      17
# 81        0.0  ...              3                             12       0
#
#     Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 82       87                          0                         15
# 32       36                         15                          2
# 81       44                          0                          8
#
#     Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 82                        8                    25     hi  93
# 32                       30                    40     hi  43
# 81                        4                    10     hi  47
#
# [3 rows x 26 columns]

# %%
mcd.sort_values('Total Fat', ascending = False).head(1)
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)    1880.0
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Dietary Fiber  \
# 82                            101        1.0  ...              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 82                         15                        8                    25
#
#     Hello  PF
# 82     hi  93
#
# [1 rows x 26 columns]

# %%
mcd.sort_values('Total Fat', ascending = False).iloc[0]
# Out:
# Category                                       Chicken & Fish
# Item                             Chicken McNuggets (40 piece)
# Serving Size                                  22.8 oz (646 g)
# Calories                                                 1880
# Calories from Fat                                        1060
# Total Fat                                                 118
# Total Fat (% Daily Value)                                 182
# Saturated Fat                                              20
# Saturated Fat (% Daily Value)                             101
# Trans Fat                                                   1
# Cholesterol                                               265
# Cholesterol (% Daily Value)                                89
# Sodium                                                   3600
# Sodium (% Daily Value)                                    150
# Carbohydrates                                             118
# Carbohydrates (% Daily Value)                              39
# Dietary Fiber                                               6
# Dietary Fiber (% Daily Value)                              24
# Sugars                                                      1
# Protein                                                    87
# Vitamin A (% Daily Value)                                   0
# Vitamin C (% Daily Value)                                  15
# Calcium (% Daily Value)                                     8
# Iron (% Daily Value)                                       25
# Hello                                                      hi
# PF                                                         93
# Name: 82, dtype: object

# %%
mcd.sort_values('Total Fat', ascending = False)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-0782523ddb4d> in <module>
# ----> 1 mcd.sort_values('Total Fat', ascending = False)[0]
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# ### groupby

# %%
for category in mcd['Category'].unique():
    print(category, 
          'mean calories:', 
          mcd[mcd['Category']  == category]['Calories'].mean())
# Out:
# Beverages mean calories: 113.70370370370371
# Coffee & Tea mean calories: 286.9148936170213
# Snacks & Sides mean calories: 245.76923076923077
# Desserts mean calories: 222.14285714285714
# Smoothies & Shakes mean calories: 531.4285714285714
# Breakfast mean calories: 526.6666666666666
# Chicken & Fish mean calories: 552.9629629629629
# Salads mean calories: 270.0
# Beef & Pork mean calories: 494.0

# %%
mcd.groupby('Category').head(1)
# Out:
#                Category                                       Item  \
# 120           Beverages                          Dr Pepper (Large)
# 144        Coffee & Tea                          Sweet Tea (Child)
# 101      Snacks & Sides                               Apple Slices
# 106            Desserts                        Kids Ice Cream Cone
# 238  Smoothies & Shakes           Mango Pineapple Smoothie (Small)
# 38            Breakfast                                 Hash Brown
# 78       Chicken & Fish                Chicken McNuggets (4 piece)
# 87               Salads  Premium Southwest Salad (without Chicken)
# 48          Beef & Pork                                  Hamburger
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 120    30 fl oz cup     270.0                  0        0.0
# 144    12 fl oz cup     110.0                  0        0.0
# 101   1.2 oz (34 g)      15.0                  0        0.0
# 106     1 oz (29 g)      45.0                 10        1.5
# 238    12 fl oz cup     210.0                  5        0.5
# 38      2 oz (56 g)     150.0                 80        9.0
# 78    2.3 oz (65 g)     190.0                110       12.0
# 87   8.1 oz (230 g)     140.0                 40        4.5
# 48    3.5 oz (98 g)     240.0                 70        8.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 120                          0            0.0                              0
# 144                          0            0.0                              0
# 101                          0            0.0                              0
# 106                          2            1.0                              4
# 238                          1            0.0                              0
# 38                          14            1.5                              6
# 78                          18            2.0                             10
# 87                           7            2.0                              9
# 48                          12            3.0                             15
#
#      Trans Fat  ...  Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  \
# 120        0.0  ...              0                              0      70
# 144        0.0  ...              0                              0      27
# 101        0.0  ...              0                              0       3
# 106        0.0  ...              0                              0       6
# 238        0.0  ...              1                              4      46
# 38         0.0  ...              2                              6       0
# 78         0.0  ...              1                              2       0
# 87         0.0  ...              6                             23       6
# 48         0.0  ...              1                              6       6
#
#      Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 120        0                          0                          0
# 144        0                          0                          0
# 101        0                          0                        160
# 106        1                          2                          0
# 238        2                         30                         20
# 38         1                          0                          2
# 78         9                          0                          2
# 87         6                        160                         25
# 48        12                          2                          2
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF
# 120                        0                     0     hi   0
# 144                        0                     0     hi   0
# 101                        2                     0     hi   0
# 106                        4                     0     hi   1
# 238                        8                     2     hi   3
# 38                         0                     2     hi   3
# 78                         0                     2     hi  10
# 87                        15                    10     hi  12
# 48                        10                    15     hi  13
#
# [9 rows x 26 columns]

# %% [markdown]
# ### aggregate

# %%
# find the average # of calories per item in category
mcd.groupby('Category').aggregate(m_calories = ('Calories', 'mean'))
# Out:
#                     m_calories
# Category
# Beef & Pork         494.000000
# Beverages           113.703704
# Breakfast           526.666667
# Chicken & Fish      552.962963
# Coffee & Tea        286.914894
# Desserts            222.142857
# Salads              270.000000
# Smoothies & Shakes  531.428571
# Snacks & Sides      245.769231

# %%
mcd.groupby('Category').aggregate(m_calories = ('Calories', 'mean')).reset_index()
# Out:
#              Category  m_calories
# 0         Beef & Pork  494.000000
# 1           Beverages  113.703704
# 2           Breakfast  526.666667
# 3      Chicken & Fish  552.962963
# 4        Coffee & Tea  286.914894
# 5            Desserts  222.142857
# 6              Salads  270.000000
# 7  Smoothies & Shakes  531.428571
# 8      Snacks & Sides  245.769231

# %%
( mcd
    .groupby('Category')
    .aggregate(m_calories = ('Calories', 'mean'))
    .reset_index() )
# Out:
#              Category  m_calories
# 0         Beef & Pork  494.000000
# 1           Beverages  113.703704
# 2           Breakfast  526.666667
# 3      Chicken & Fish  552.962963
# 4        Coffee & Tea  286.914894
# 5            Desserts  222.142857
# 6              Salads  270.000000
# 7  Smoothies & Shakes  531.428571
# 8      Snacks & Sides  245.769231

# %%
mcd_grp = mcd.groupby('Category')
mcd_agg = mcd_grp.aggregate(m_calories = ('Calories', 'mean'))

# %%
mcd_summary = mcd_agg.reset_index()
mcd_summary
# Out:
#              Category  m_calories
# 0         Beef & Pork  494.000000
# 1           Beverages  113.703704
# 2           Breakfast  526.666667
# 3      Chicken & Fish  552.962963
# 4        Coffee & Tea  286.914894
# 5            Desserts  222.142857
# 6              Salads  270.000000
# 7  Smoothies & Shakes  531.428571
# 8      Snacks & Sides  245.769231

# %%
mcd.aggregate(mean_calories = ('Calories', 'mean'))
# Out:
#                 Calories
# mean_calories  369.69112

# %%
mcd['Calories'].mean()
# Out:
# 369.6911196911197

# %% [markdown]
# ### chaining operations
#
# ## tasks
#
# ### Find the breakfast menu item with the fewest calories

# %%
mcd[ mcd['Category'] == 'Breakfast'].sort_values('Calories').head(1)
# Out:
#      Category        Item Serving Size  Calories  Calories from Fat  \
# 38  Breakfast  Hash Brown  2 oz (56 g)     150.0                 80
#
#     Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 38        9.0                         14            1.5
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Dietary Fiber  \
# 38                              6        0.0  ...              2
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 38                              6       0        1                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 38                          2                        0                     2
#
#     Hello  PF
# 38     hi   3
#
# [1 rows x 26 columns]

# %%
mcd[ mcd['Category'] == 'Breakfast'].sort_values('Calories').head(1)
# Out:
#      Category        Item Serving Size  Calories  Calories from Fat  \
# 38  Breakfast  Hash Brown  2 oz (56 g)     150.0                 80
#
#     Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 38        9.0                         14            1.5
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Dietary Fiber  \
# 38                              6        0.0  ...              2
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 38                              6       0        1                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 38                          2                        0                     2
#
#     Hello  PF
# 38     hi   3
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Find the highest vul_index food
#
# vul_index = 10*(protein grams + fiber grams)/calories

# %%
mcd['vul-index'] = 10*(mcd['Protein'] + mcd['Dietary Fiber'])/mcd['Calories']

# %%
(mcd [ ~ mcd['vul-index'].isna() & ~np.isinf(mcd['vul-index'])]
 .sort_values('vul-index', ascending=False) )
# Out:
#          Category                                            Item  \
# 86         Salads  Premium Bacon Ranch Salad with Grilled Chicken
# 89         Salads    Premium Southwest Salad with Grilled Chicken
# 163  Coffee & Tea                            Nonfat Latte (Small)
# 165  Coffee & Tea                            Nonfat Latte (Large)
# 164  Coffee & Tea                           Nonfat Latte (Medium)
# ..            ...                                             ...
# 112     Beverages                       Coca-Cola Classic (Large)
# 119     Beverages                              Dr Pepper (Medium)
# 113     Beverages                       Coca-Cola Classic (Child)
# 144  Coffee & Tea                               Sweet Tea (Child)
# 120     Beverages                               Dr Pepper (Large)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 86    8.5 oz (241 g)     220.0                 80        8.0
# 89   11.8 oz (335 g)     290.0                 80        8.0
# 163     12 fl oz cup     100.0                  0        0.0
# 165     20 fl oz cup     170.0                  0        0.5
# 164     16 fl oz cup     130.0                  0        0.0
# ..               ...       ...                ...        ...
# 112     30 fl oz cup     280.0                  0        0.0
# 119     21 fl oz cup     190.0                  0        0.0
# 113     12 fl oz cup     100.0                  0        0.0
# 144     12 fl oz cup     110.0                  0        0.0
# 120     30 fl oz cup     270.0                  0        0.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 86                          13            4.0                             20
# 89                          13            2.5                             13
# 163                          0            0.0                              0
# 165                          1            0.0                              0
# 164                          0            0.0                              0
# ..                         ...            ...                            ...
# 112                          0            0.0                              0
# 119                          0            0.0                              0
# 113                          0            0.0                              0
# 144                          0            0.0                              0
# 120                          0            0.0                              0
#
#      Trans Fat  ...  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 86         0.0  ...                             10       4       29
# 89         0.0  ...                             28      10       27
# 163        0.0  ...                              3      13       10
# 165        0.0  ...                              6      21       16
# 164        0.0  ...                              4      16       12
# ..         ...  ...                            ...     ...      ...
# 112        0.0  ...                              0      76        0
# 119        0.0  ...                              0      51        0
# 113        0.0  ...                              0      28        0
# 144        0.0  ...                              0      27        0
# 120        0.0  ...                              0      70        0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 86                         110                         30
# 89                         170                         30
# 163                         10                          0
# 165                         15                          0
# 164                         15                          0
# ..                         ...                        ...
# 112                          0                          0
# 119                          0                          0
# 113                          0                          0
# 144                          0                          0
# 120                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Hello  PF  vul-index
# 86                        15                     8     hi  31   1.409091
# 89                        15                    15     hi  34   1.172414
# 163                       30                     0     hi  11   1.100000
# 165                       50                     2     hi  17   1.000000
# 164                       40                     0     hi  13   1.000000
# ..                       ...                   ...    ...  ..        ...
# 112                        0                     0     hi   0   0.000000
# 119                        0                     0     hi   0   0.000000
# 113                        0                     0     hi   0   0.000000
# 144                        0                     0     hi   0   0.000000
# 120                        0                     0     hi   0   0.000000
#
# [244 rows x 27 columns]

# %%
(mcd[mcd['Calories'] > 0]
.sort_values('vul-index', ascending = False)
.head(1))
# Out:
#    Category                                            Item    Serving Size  \
# 86   Salads  Premium Bacon Ranch Salad with Grilled Chicken  8.5 oz (241 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 86     220.0                 80        8.0                         13
#
#     Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 86            4.0                             20        0.0  ...
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 86                             10       4       29                        110
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 86                         30                       15                     8
#
#     Hello  PF  vul-index
# 86     hi  31   1.409091
#
# [1 rows x 27 columns]

# %% [markdown]
# ### calculate mean, max calories, and n for each category
#
#
#
#
# ### pull out max calorie item for each category
